# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
nba_data = pd.read_csv("../Resources/cleaned_df.csv")

# %%
nba_data.head()
# Out:
#    YEAR             PLAYER                   TEAM    SALARY  AGE  GP   W  L  \
# 0  2015      Stephen Curry  Golden State Warriors  11370786   28  79  71  8
# 1  2015   Shaun Livingston  Golden State Warriors   5543725   30  78  69  9
# 2  2015  Marreese Speights  Golden State Warriors   3815000   28  72  64  8
# 3  2015    Leandro Barbosa  Golden State Warriors   2500000   33  68  60  8
# 4  2015      Klay Thompson  Golden State Warriors  15501000   26  80  71  9
#
#     MIN   PTS  ...  AST  TOV  STL  BLK   PF    FP  DD2  TD3   +/-   RK
# 0  34.2  30.1  ...  6.7  3.3  2.1  0.2  2.0  50.3   15    2  12.9   61
# 1  19.5   6.3  ...  3.0  1.0  0.7  0.3  1.8  15.6    0    0   2.7  132
# 2  11.6   7.1  ...  0.8  0.9  0.3  0.5  1.6  13.7    1    0   0.2  183
# 3  15.9   6.4  ...  1.2  0.8  0.6  0.1  1.6  11.8    0    0   0.6  243
# 4  33.3  22.1  ...  2.1  1.7  0.8  0.6  1.9  32.2    0    0  10.5   31
#
# [5 rows x 32 columns]

# %%
x_PTS = nba_data['PTS']
y_Salary = nba_data['SALARY']
plt.scatter(x_PTS,y_Salary,marker = 'o',edgecolors = 'blue')
plt.title("Points vs. Salary")
plt.xlabel("Points")
plt.ylabel("Salary")
plt.grid()
plt.yticks(np.arange(0,50000000,10000000))
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_PTS, y_Salary)
regress_values = x_PTS * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_PTS,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.6794778707294548

# %%
x_AST = nba_data['AST']
y_Salary = nba_data['SALARY']
plt.scatter(x_AST,y_Salary,marker = 'o',edgecolors = 'blue')
plt.title("Assists vs. Salary")
plt.xlabel("Assists")
plt.ylabel("Salary")
plt.grid()
plt.yticks(np.arange(0,50000000,10000000))
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_AST, y_Salary)
regress_values = x_AST * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_AST,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.5732142011218708

# %%
x_3pt = nba_data['3P%']
y_Salary = nba_data['SALARY']
plt.scatter(x_3pt,y_Salary,marker = 'o',edgecolors = 'blue')
plt.title("3P% vs. Salary")
plt.xlabel("3P%")
plt.ylabel("Salary")
plt.grid()
plt.yticks(np.arange(0,50000000,10000000))
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_3pt, y_Salary)
regress_values = x_3pt * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_3pt,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.18097481591565873

# %%
df_corr = nba_data.corr()
df_corr.unstack().sort_values()
df_corr.head(15)
# Out:
#             YEAR    SALARY       AGE        GP         W         L       MIN  \
# YEAR    1.000000  0.102773 -0.142956 -0.333157 -0.242190 -0.256644  0.003758
# SALARY  0.102773  1.000000  0.275272  0.151545  0.188094  0.020845  0.610930
# AGE    -0.142956  0.275272  1.000000  0.123487  0.215553 -0.059660  0.117925
# GP     -0.333157  0.151545  0.123487  1.000000  0.801994  0.677995  0.409113
# W      -0.242190  0.188094  0.215553  0.801994  1.000000  0.104669  0.266243
# L      -0.256644  0.020845 -0.059660  0.677995  0.104669  1.000000  0.353505
# MIN     0.003758  0.610930  0.117925  0.409113  0.266243  0.353505  1.000000
# PTS     0.043453  0.679478  0.075812  0.321266  0.255939  0.219927  0.846654
# FGM     0.048520  0.660569  0.052647  0.342902  0.269174  0.239661  0.851831
# FGA     0.043251  0.654596  0.060736  0.297230  0.201015  0.247497  0.864520
# FG%    -0.042102  0.065592  0.031428  0.262630  0.306208  0.060442  0.078912
# ...
