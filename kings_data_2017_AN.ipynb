# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
kings_data = pd.read_csv("../Resources/cleaned_df.csv")

# %%
kings_data.head()
# Out:
#    YEAR             PLAYER                   TEAM    SALARY  AGE  GP   W  L  \
# 0  2015      Stephen Curry  Golden State Warriors  11370786   28  79  71  8
# 1  2015   Shaun Livingston  Golden State Warriors   5543725   30  78  69  9
# 2  2015  Marreese Speights  Golden State Warriors   3815000   28  72  64  8
# 3  2015    Leandro Barbosa  Golden State Warriors   2500000   33  68  60  8
# 4  2015      Klay Thompson  Golden State Warriors  15501000   26  80  71  9
#
#     MIN   PTS  ...  AST  TOV  STL  BLK   PF    FP  DD2  TD3   +/-   RK
# 0  34.2  30.1  ...  6.7  3.3  2.1  0.2  2.0  50.3   15    2  12.9   61
# 1  19.5   6.3  ...  3.0  1.0  0.7  0.3  1.8  15.6    0    0   2.7  132
# 2  11.6   7.1  ...  0.8  0.9  0.3  0.5  1.6  13.7    1    0   0.2  183
# 3  15.9   6.4  ...  1.2  0.8  0.6  0.1  1.6  11.8    0    0   0.6  243
# 4  33.3  22.1  ...  2.1  1.7  0.8  0.6  1.9  32.2    0    0  10.5   31
#
# [5 rows x 32 columns]

# %%
kings_cleansed_df = kings_data.loc[kings_data['TEAM']== 'Sacramento Kings']
kings_cleansed_df = kings_cleansed_df.loc[kings_cleansed_df['YEAR']== 2017]
kings_cleansed_df
# Out:
#      YEAR                PLAYER              TEAM    SALARY  AGE  GP   W   L  \
# 259  2017         Zach Randolph  Sacramento Kings  12307692   36  59  18  41
# 260  2017   Willie Cauley-Stein  Sacramento Kings   3704160   24  73  23  50
# 261  2017          Vince Carter  Sacramento Kings   8000000   41  58  20  38
# 262  2017       Skal Labissiere  Sacramento Kings   1312611   22  60  19  41
# 263  2017          Kosta Koufos  Sacramento Kings   8393000   29  71  22  49
# 264  2017        Justin Jackson  Sacramento Kings   2365560   23  68  21  47
# 265  2017  Georgios Papagiannis  Sacramento Kings    185397   20  16   3  13
# 266  2017           George Hill  Sacramento Kings  19000000   32  43  13  30
# 267  2017        Garrett Temple  Sacramento Kings   8000000   32  65  23  42
# 268  2017          De'Aaron Fox  Sacramento Kings   4609200   20  73  24  49
# 269  2017           Buddy Hield  Sacramento Kings   3675480   25  80  27  53
# 270  2017     Bogdan Bogdanovic  Sacramento Kings   9412280   25  78  26  52
#
#       MIN   PTS  ...  AST  TOV  STL  BLK   PF    FP  DD2  TD3  +/-   RK
# 259  25.6  14.5  ...  2.2  2.0  0.7  0.2  2.0  26.5    8    0 -6.0   97
# 260  28.0  12.8  ...  2.4  1.5  1.1  0.9  2.5  29.1   12    0 -4.4  227
# 261  17.7   5.4  ...  1.2  0.6  0.7  0.4  1.7  13.1    0    0 -1.2  142
# 262  20.7   8.7  ...  1.2  1.2  0.4  0.8  2.2  18.7    3    0 -2.0  416
# 263  19.6   6.7  ...  1.2  0.7  0.7  0.5  2.1  19.2    6    0 -3.1  137
# 264  22.2   6.7  ...  1.1  0.6  0.4  0.2  1.2  12.8    0    0 -3.5  283
# 265   7.4   2.1  ...  0.6  0.5  0.1  0.4  0.8   6.7    0    0 -1.3  579
# 266  26.6  10.3  ...  2.8  1.4  0.9  0.3  1.7  19.8    0    0 -5.7   43
# 267  24.8   8.4  ...  1.9  1.2  0.9  0.4  2.1  16.7    0    0 -4.0  139
# 268  27.7  11.6  ...  4.4  2.4  1.0  0.3  2.2  22.8    3    0 -5.7  206
# 269  25.3  13.5  ...  1.9  1.6  1.1  0.3  1.9  23.5    0    0 -1.9  228
# 270  27.9  11.8  ...  3.3  1.6  0.9  0.2  2.2  21.9    0    0 -4.6  124
#
# [12 rows x 32 columns]

# %%
x_PTS = kings_cleansed_df['PTS']
y_Salary = kings_cleansed_df['SALARY']
plt.scatter(x_PTS,y_Salary,marker = 'o',edgecolors = 'blue')
plt.title("Points vs. Salary")
plt.xlabel("Points")
plt.ylabel("Salary")
plt.grid()
plt.yticks(np.arange(0,20000000,1000000))
# Out:
# ([<matplotlib.axis.YTick at 0x20148aba2b0>,
#   <matplotlib.axis.YTick at 0x20148aaeba8>,
#   <matplotlib.axis.YTick at 0x20148845ba8>,
#   <matplotlib.axis.YTick at 0x20148adea58>,
#   <matplotlib.axis.YTick at 0x20148adef28>,
#   <matplotlib.axis.YTick at 0x20148afc438>,
#   <matplotlib.axis.YTick at 0x20148adee80>,
#   <matplotlib.axis.YTick at 0x20148afcac8>,
#   <matplotlib.axis.YTick at 0x20148b030b8>,
#   <matplotlib.axis.YTick at 0x20148b035f8>,
#   <matplotlib.axis.YTick at 0x20148b03b70>,
#   <matplotlib.axis.YTick at 0x20148b0b160>,
#   <matplotlib.axis.YTick at 0x20148b0b6a0>,
#   <matplotlib.axis.YTick at 0x20148b0bc18>,
#   <matplotlib.axis.YTick at 0x20148b121d0>,
#   <matplotlib.axis.YTick at 0x20148b0bcc0>,
#   <matplotlib.axis.YTick at 0x20148b03550>,
#   <matplotlib.axis.YTick at 0x20148b12748>,
#   <matplotlib.axis.YTick at 0x20148b12cc0>,
#   <matplotlib.axis.YTick at 0x20148b18278>],
#  <a list of 20 Text yticklabel objects>)

# %%
x_assists = kings_cleansed_df['AST']
y_salary = kings_cleansed_df['SALARY']
plt.scatter(x_assists,y_Salary,marker = 'o',edgecolors = 'red')
plt.title("Assists vs. Salary")
plt.xlabel("Assists")
plt.ylabel("Salary")
plt.grid()
plt.yticks(np.arange(0,20000000,1000000))
# Out:
# ([<matplotlib.axis.YTick at 0x24fffe87048>,
#   <matplotlib.axis.YTick at 0x24fffe72940>,
#   <matplotlib.axis.YTick at 0x24fffe6e198>,
#   <matplotlib.axis.YTick at 0x24fffeb7710>,
#   <matplotlib.axis.YTick at 0x24fffeb7be0>,
#   <matplotlib.axis.YTick at 0x24fffebe128>,
#   <matplotlib.axis.YTick at 0x24fffeb7d30>,
#   <matplotlib.axis.YTick at 0x24fffebe780>,
#   <matplotlib.axis.YTick at 0x24fffebecf8>,
#   <matplotlib.axis.YTick at 0x24fffec42b0>,
#   <matplotlib.axis.YTick at 0x24fffec4828>,
#   <matplotlib.axis.YTick at 0x24fffec4da0>,
#   <matplotlib.axis.YTick at 0x24fffecc358>,
#   <matplotlib.axis.YTick at 0x24fffecc8d0>,
#   <matplotlib.axis.YTick at 0x24fffecce48>,
#   <matplotlib.axis.YTick at 0x24fffeccf28>,
#   <matplotlib.axis.YTick at 0x24fffec4208>,
#   <matplotlib.axis.YTick at 0x24fffed4400>,
#   <matplotlib.axis.YTick at 0x24fffed4978>,
#   <matplotlib.axis.YTick at 0x24fffed4ef0>],
#  <a list of 20 Text yticklabel objects>)

# %%
x_rebound = kings_cleansed_df['REB']
y_salary = kings_cleansed_df['SALARY']
plt.scatter(x_rebound,y_salary,marker = 'o',edgecolors = 'purple')
plt.title("Rebounds vs. Salary")
plt.xlabel("Rebounds")
plt.ylabel("Salary")
plt.grid()
plt.yticks(np.arange(0,20000000,1000000))
# Out:
# ([<matplotlib.axis.YTick at 0x20148b98c18>,
#   <matplotlib.axis.YTick at 0x20148b984a8>,
#   <matplotlib.axis.YTick at 0x20148b85198>,
#   <matplotlib.axis.YTick at 0x20148bd12e8>,
#   <matplotlib.axis.YTick at 0x20148bd17b8>,
#   <matplotlib.axis.YTick at 0x20148bd1c88>,
#   <matplotlib.axis.YTick at 0x20148bd1898>,
#   <matplotlib.axis.YTick at 0x20148bd6320>,
#   <matplotlib.axis.YTick at 0x20148bd6898>,
#   <matplotlib.axis.YTick at 0x20148bd6e10>,
#   <matplotlib.axis.YTick at 0x20148bdd3c8>,
#   <matplotlib.axis.YTick at 0x20148bdd940>,
#   <matplotlib.axis.YTick at 0x20148bddeb8>,
#   <matplotlib.axis.YTick at 0x20148be5470>,
#   <matplotlib.axis.YTick at 0x20148be59e8>,
#   <matplotlib.axis.YTick at 0x20148bdda20>,
#   <matplotlib.axis.YTick at 0x20148bd6198>,
#   <matplotlib.axis.YTick at 0x20148be5ef0>,
#   <matplotlib.axis.YTick at 0x20148bec4a8>,
#   <matplotlib.axis.YTick at 0x20148beca20>],
#  <a list of 20 Text yticklabel objects>)

# %%
x_three = kings_cleansed_df['3P%']
y_salary = kings_cleansed_df['SALARY']
plt.scatter(x_three,y_salary,marker = 'o',edgecolors = 'green')
plt.title("3P% vs. Salary")
plt.xlabel("3P%")
plt.ylabel("Salary")
plt.grid()
plt.yticks(np.arange(0,20000000,1000000))
# Out:
# ([<matplotlib.axis.YTick at 0x24f81023fd0>,
#   <matplotlib.axis.YTick at 0x24f81023860>,
#   <matplotlib.axis.YTick at 0x24f810172b0>,
#   <matplotlib.axis.YTick at 0x24f8104c5f8>,
#   <matplotlib.axis.YTick at 0x24f8104cac8>,
#   <matplotlib.axis.YTick at 0x24f8104ce80>,
#   <matplotlib.axis.YTick at 0x24f81052518>,
#   <matplotlib.axis.YTick at 0x24f8104c5c0>,
#   <matplotlib.axis.YTick at 0x24f81052c18>,
#   <matplotlib.axis.YTick at 0x24f8105a080>,
#   <matplotlib.axis.YTick at 0x24f8105a588>,
#   <matplotlib.axis.YTick at 0x24f8105ab00>,
#   <matplotlib.axis.YTick at 0x24f810600f0>,
#   <matplotlib.axis.YTick at 0x24f81060630>,
#   <matplotlib.axis.YTick at 0x24f81060ba8>,
#   <matplotlib.axis.YTick at 0x24f81068160>,
#   <matplotlib.axis.YTick at 0x24f81060438>,
#   <matplotlib.axis.YTick at 0x24f8105a668>,
#   <matplotlib.axis.YTick at 0x24f81068320>,
#   <matplotlib.axis.YTick at 0x24f81068cc0>],
#  <a list of 20 Text yticklabel objects>)

# %%
x_free = kings_cleansed_df['FT%']
y_salary = kings_cleansed_df['SALARY']
plt.scatter(x_free,y_salary,marker = 'o',edgecolors = 'blue')
plt.title("FT% vs. Salary")
plt.xlabel("FT%")
plt.ylabel("Salary")
plt.grid()
plt.yticks(np.arange(0,20000000,1000000))
# Out:
# ([<matplotlib.axis.YTick at 0x20148c35be0>,
#   <matplotlib.axis.YTick at 0x20148c354e0>,
#   <matplotlib.axis.YTick at 0x20148c28278>,
#   <matplotlib.axis.YTick at 0x20148c5d208>,
#   <matplotlib.axis.YTick at 0x20148c5d6d8>,
#   <matplotlib.axis.YTick at 0x20148c5dba8>,
#   <matplotlib.axis.YTick at 0x20148c62160>,
#   <matplotlib.axis.YTick at 0x20148c5df60>,
#   <matplotlib.axis.YTick at 0x20148c620f0>,
#   <matplotlib.axis.YTick at 0x20148c62be0>,
#   <matplotlib.axis.YTick at 0x20148c68198>,
#   <matplotlib.axis.YTick at 0x20148c68710>,
#   <matplotlib.axis.YTick at 0x20148c68c88>,
#   <matplotlib.axis.YTick at 0x20148c6f240>,
#   <matplotlib.axis.YTick at 0x20148c6f7b8>,
#   <matplotlib.axis.YTick at 0x20148c6fd30>,
#   <matplotlib.axis.YTick at 0x20148c6fe10>,
#   <matplotlib.axis.YTick at 0x20148c68240>,
#   <matplotlib.axis.YTick at 0x20148c772e8>,
#   <matplotlib.axis.YTick at 0x20148c77860>],
#  <a list of 20 Text yticklabel objects>)
